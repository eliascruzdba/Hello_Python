# %% [markdown]
# # Importação de um Dataframe Pandas para análise através do Jupyter Notebook

# %% [markdown]
# Olá tudo bem?!?! Aqui é Elias Cruz e pouco mais de 8 meses tive um desafio em pesquisar sobre uma linguagem que vinha crescendo e em meu curso de "CIÊNCIA DE DADOS E BIG DATA" fui desafiado a conhecer e explorar essa linguagem para realiação da entrega do meu trabalho de conclusão de curso.
#
# “O segredo de progredir é começar.
#
# O segredo de começar é dividir as tarefas árduas e complicadas em tarefas pequenas e fáceis de executar, e depois começar pela primeira” (Mark Twain)
#
# Deixo aqui alguns passos que me ajudaram muito a iniciar essa caminhada.
#
# Lets Go!!!

# %% [markdown]
# # ...mas o que preciso para ler uma base de dados?

# %% [markdown]
# ### Importando bibliotecas

# %% [markdown]
# A Biblioteca Padrão do Python é uma coleção de módulos de script acessíveis a um programa Python para simplificar o processo de programação e remover a necessidade de reescrever os comandos mais usados.

# %%
import pandas as pd 
import os

# %% [markdown]
# ### Navegando até o caminho da pasta local.

# %%
os.chdir('C:\\Temp\\')

# %% [markdown]
# ### Comando para verificar a pasta em que se encontra atualmente

# %%
pwd
# Out:
# 'C:\\Temp'

# %% [markdown]
# ### Visualizando o Arquivo a ser utilizado com o comando "ls"

# %%
ls cat_vitimas.csv
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 622D-FA5C
#
#  Directory of C:\Temp
#
# 18/04/2022  23:25         5.940.506 cat_vitimas.csv
#                1 File(s)      5.940.506 bytes
#                0 Dir(s)   3.690.602.496 bytes free

# %% [markdown]
# ### CSV Files - Realizando a importação da Base ".csv" através do Pandas

# %% [markdown]
# Quem mexe no dia a dia com arquivos pesados as vezes se vê de forma repetitiva em abrir o Excel importar o .csv em seguida separar como colunas fixando separador como ponto...aqui em python essa visualização é realizada de forma rápida e dinâmica apenas apontando o nome do arquivo e a pasta.

# %%
df = pd.read_csv('cat_vitimas.csv', delimiter=';')

# %% [markdown]
# ### Visualizando sua base / dataframe

# %%
df
# Out:
#              data_extracao  longitude   latitude  idacidente  \
# 0      2022-04-01 01:34:14 -51.186166 -30.027910      630905
# 1      2022-04-01 01:34:14 -51.190718 -29.999008      630968
# 2      2022-04-01 01:34:14 -51.212812 -30.051041      630978
# 3      2022-04-01 01:34:14 -51.113918 -30.015335      630982
# 4      2022-04-01 01:34:14 -51.205781 -30.030474      630988
# ...                    ...        ...        ...         ...
# 27955  2022-04-01 01:34:14 -51.196813 -30.048567      693761
# 27956  2022-04-01 01:34:14 -51.137406 -30.157836      693768
# 27957  2022-04-01 01:34:14 -51.201729 -30.011278      693819
# 27958  2022-04-01 01:34:14 -51.148395 -30.012808      693901
# 27959  2022-04-01 01:34:14 -51.196527 -30.033121      693907
#
#                       data              hora  idade           sexo sit_vitima  \
# 0      2017-01-04 00:00:00  09:50:00.0000000    NaN  NAO INFORMADO   CONDUTOR
# ...

# %% [markdown]
# ### Excel Files - Realizando a importação da Base ".xlsx" através do Pandas através do nome da "sheet".

# %% [markdown]
# Quem mexe com excel sabe a necessidade de obter uma visualização rápida do arquivos e quem sabe ter o poder de realizar uma análise utilizando mais recursos como estatísticas e visualizações.

# %%
df_excel = pd.read_excel('dataframe.xlsx', sheet_name='principal')

# %%
df_excel
# Out:
#    Unnamed: 0     COUNTRY      POP      AREA       GDP       CONT    IND_DAY
# 0         CHN       China  1398.72   9596.96  12234.78       Asia        NaT
# 1         IND       India  1351.16   3287.26   2575.67       Asia 1947-08-15
# 2         USA          US   329.74   9833.52  19485.39  N.America 1776-07-04
# 3         IDN   Indonesia   268.07   1910.93   1015.54       Asia 1945-08-17
# 4         BRA      Brazil   210.32   8515.77   2055.51  S.America 1822-09-07
# 5         PAK    Pakistan   205.71    881.91    302.14       Asia 1947-08-14
# 6         NGA     Nigeria   200.96    923.77    375.77     Africa 1960-10-01
# 7         BGD  Bangladesh   167.09    147.57    245.63       Asia 1971-03-26
# 8         RUS      Russia   146.79  17098.25   1530.75        NaN 1992-06-12
# 9         MEX      Mexico   126.58   1964.38   1158.23  N.America 1810-09-16
# 10        JPN       Japan   126.22    377.97   4872.42       Asia        NaT
# ...
